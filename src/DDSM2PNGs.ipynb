# %% [markdown]
# One way to navigate the DDSM directories in order to acquire the following information from each DDSM case using the .ics file:
# * Filename
# * The type of digitizer used (can be one of: 'DBA', 'HOWTEK' and 'LUMISYS')
# * LEFT_CC, LEFT_MLO, RIGHT_CC, RIGHT_MLO image resolutions (rows x columns) ... 4 images per case
#
# This information can be used in additional code to convert DDSM's Lossless JPEG images to PNGs. (That code needs a Windows RTE given the required utilities jpeg.exe & ddsmraw2pnm.exe)

# %%
__version__   = '0.0.1'
__status__    = 'Development'

# %%
import os, sys
import re
import pandas as pd

# %%
def read_ics(dir_name, fname):
    fpath = os.path.join(dir_name, fname)
    
    try: 
        with open(fpath) as fobj:
            for line in fobj:
                if line.startswith('filename'):
                    fn = (line.split()[1]).replace('-', '_')
                if line.startswith('DIGITIZER'):
                    digitizer = line.split()[1]
                if line.startswith('LEFT_CC'):
                    LEFT_CC_rows = line.split()[2]
                    LEFT_CC_cols = line.split()[4]
                if line.startswith('LEFT_MLO'):
                    LEFT_MLO_rows = line.split()[2]
                    LEFT_MLO_cols = line.split()[4]
                if line.startswith('RIGHT_CC'):
                    RIGHT_CC_rows = line.split()[2]
                    RIGHT_CC_cols= line.split()[4]
                if line.startswith('RIGHT_MLO'):
                    RIGHT_MLO_rows = line.split()[2]
                    RIGHT_MLO_cols= line.split()[4]
            
            meta = [
                {'fn': fn+'.LEFT_CC.LJPEG',   'rows': LEFT_CC_rows,   'cols': LEFT_CC_cols,   'digitizer': digitizer},
                {'fn': fn+'.LEFT_MLO.LJPEG',  'rows': LEFT_MLO_rows,  'cols': LEFT_MLO_cols,  'digitizer': digitizer},
                {'fn': fn+'.RIGHT_CC.LJPEG',  'rows': RIGHT_CC_rows,  'cols': RIGHT_CC_cols,  'digitizer': digitizer},
                {'fn': fn+'.RIGHT_MLO.LJPEG', 'rows': RIGHT_MLO_rows, 'cols': RIGHT_MLO_cols, 'digitizer': digitizer},
            ]
        
            return pd.DataFrame(meta)
    except IOError as error:
        print('File Error Encountered: {0} {1}'.format(fname, error[1]))
    except UnboundLocalError as error:
        print ('In directory {0}, problem encountered with DDSM files. Check directory.'.format(dir_name))
        sys.exit(1)

# %%
def create_PNGs(start_dir, DDSM_dir):
    
    os.chdir(DDSM_dir)
    for dir_name, subdir_list, file_list in os.walk(DDSM_dir):
        for fname in file_list:
            if re.match(r'.*[.]ics', fname):
                print 'In directory: {0}\t ... found the file {1}'.format(dir_name, fname)
                meta = read_ics(dir_name, fname)
                print meta[['fn', 'rows', 'cols', 'digitizer']], '\n'
                # Call functions to generate 4 PNM files per case using Dr. Chris Rose's utilities jpeg.exe & ddsmraw2pnm.exe
                # For each PNM file, generate a PNG file using NETpbm's pnmtopng function
                
    os.chdir(start_dir)

# %%
start_dir = os.getcwd()

create_PNGs(start_dir, '/Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases' )
# Out:
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3159	 ... found the file B-3159-1.ics
#                          fn  rows  cols digitizer
# 0    B_3159_1.LEFT_CC.LJPEG  4544  3120   LUMISYS
# 1   B_3159_1.LEFT_MLO.LJPEG  4536  3112   LUMISYS
# 2   B_3159_1.RIGHT_CC.LJPEG  4616  3088   LUMISYS
# 3  B_3159_1.RIGHT_MLO.LJPEG  4616  3088   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3160	 ... found the file B-3160-1.ics
#                          fn  rows  cols digitizer
# 0    B_3160_1.LEFT_CC.LJPEG  4624  3056   LUMISYS
# 1   B_3160_1.LEFT_MLO.LJPEG  4560  3024   LUMISYS
# 2   B_3160_1.RIGHT_CC.LJPEG  4584  3040   LUMISYS
# 3  B_3160_1.RIGHT_MLO.LJPEG  4600  3032   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3161	 ... found the file B-3161-1.ics
#                          fn  rows  cols digitizer
# 0    B_3161_1.LEFT_CC.LJPEG  4568  3064   LUMISYS
# 1   B_3161_1.LEFT_MLO.LJPEG  4528  3056   LUMISYS
# 2   B_3161_1.RIGHT_CC.LJPEG  4536  3032   LUMISYS
# 3  B_3161_1.RIGHT_MLO.LJPEG  4576  3048   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3162	 ... found the file B-3162-1.ics
#                          fn  rows  cols digitizer
# 0    B_3162_1.LEFT_CC.LJPEG  4576  3088   LUMISYS
# 1   B_3162_1.LEFT_MLO.LJPEG  4584  3024   LUMISYS
# 2   B_3162_1.RIGHT_CC.LJPEG  4568  3072   LUMISYS
# 3  B_3162_1.RIGHT_MLO.LJPEG  4568  3048   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3163	 ... found the file B-3163-1.ics
#                          fn  rows  cols digitizer
# 0    B_3163_1.LEFT_CC.LJPEG  4640  3104   LUMISYS
# 1   B_3163_1.LEFT_MLO.LJPEG  4480  3104   LUMISYS
# 2   B_3163_1.RIGHT_CC.LJPEG  4640  3104   LUMISYS
# 3  B_3163_1.RIGHT_MLO.LJPEG  4576  3080   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3164	 ... found the file B-3164-1.ics
#                          fn  rows  cols digitizer
# 0    B_3164_1.LEFT_CC.LJPEG  4560  3064   LUMISYS
# 1   B_3164_1.LEFT_MLO.LJPEG  4600  3048   LUMISYS
# 2   B_3164_1.RIGHT_CC.LJPEG  4608  3072   LUMISYS
# 3  B_3164_1.RIGHT_MLO.LJPEG  4632  3016   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3165	 ... found the file B-3165-1.ics
#                          fn  rows  cols digitizer
# 0    B_3165_1.LEFT_CC.LJPEG  4552  3016   LUMISYS
# 1   B_3165_1.LEFT_MLO.LJPEG  4528  3032   LUMISYS
# 2   B_3165_1.RIGHT_CC.LJPEG  4568  3064   LUMISYS
# 3  B_3165_1.RIGHT_MLO.LJPEG  4624  3032   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3166	 ... found the file B-3166-1.ics
#                          fn  rows  cols digitizer
# 0    B_3166_1.LEFT_CC.LJPEG  5680  4064   LUMISYS
# 1   B_3166_1.LEFT_MLO.LJPEG  5704  4128   LUMISYS
# 2   B_3166_1.RIGHT_CC.LJPEG  5744  4008   LUMISYS
# 3  B_3166_1.RIGHT_MLO.LJPEG  5760  4080   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3167	 ... found the file B-3167-1.ics
#                          fn  rows  cols digitizer
# 0    B_3167_1.LEFT_CC.LJPEG  4552  3008   LUMISYS
# 1   B_3167_1.LEFT_MLO.LJPEG  4768  3248   LUMISYS
# 2   B_3167_1.RIGHT_CC.LJPEG  4600  3104   LUMISYS
# 3  B_3167_1.RIGHT_MLO.LJPEG  4632  3072   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3168	 ... found the file B-3168-1.ics
#                          fn  rows  cols digitizer
# 0    B_3168_1.LEFT_CC.LJPEG  4488  3040   LUMISYS
# 1   B_3168_1.LEFT_MLO.LJPEG  4552  3072   LUMISYS
# 2   B_3168_1.RIGHT_CC.LJPEG  4552  3064   LUMISYS
# 3  B_3168_1.RIGHT_MLO.LJPEG  4584  3056   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3169	 ... found the file B-3169-1.ics
#                          fn  rows  cols digitizer
# 0    B_3169_1.LEFT_CC.LJPEG  4632  3112   LUMISYS
# 1   B_3169_1.LEFT_MLO.LJPEG  4440  3120   LUMISYS
# 2   B_3169_1.RIGHT_CC.LJPEG  4544  3072   LUMISYS
# 3  B_3169_1.RIGHT_MLO.LJPEG  4624  3112   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3170	 ... found the file B-3170-1.ics
#                          fn  rows  cols digitizer
# 0    B_3170_1.LEFT_CC.LJPEG  4624  3112   LUMISYS
# 1   B_3170_1.LEFT_MLO.LJPEG  4624  3128   LUMISYS
# 2   B_3170_1.RIGHT_CC.LJPEG  4624  3096   LUMISYS
# 3  B_3170_1.RIGHT_MLO.LJPEG  4592  3104   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3171	 ... found the file B-3171-1.ics
#                          fn  rows  cols digitizer
# 0    B_3171_1.LEFT_CC.LJPEG  5664  3984   LUMISYS
# 1   B_3171_1.LEFT_MLO.LJPEG  5664  4040   LUMISYS
# 2   B_3171_1.RIGHT_CC.LJPEG  5776  4000   LUMISYS
# 3  B_3171_1.RIGHT_MLO.LJPEG  5800  3984   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3172	 ... found the file B-3172-1.ics
#                          fn  rows  cols digitizer
# 0    B_3172_1.LEFT_CC.LJPEG  5728  3992   LUMISYS
# 1   B_3172_1.LEFT_MLO.LJPEG  5696  4128   LUMISYS
# 2   B_3172_1.RIGHT_CC.LJPEG  5688  3960   LUMISYS
# 3  B_3172_1.RIGHT_MLO.LJPEG  5752  4120   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3173	 ... found the file B-3173-1.ics
#                          fn  rows  cols digitizer
# 0    B_3173_1.LEFT_CC.LJPEG  4512  3056   LUMISYS
# 1   B_3173_1.LEFT_MLO.LJPEG  4544  3080   LUMISYS
# 2   B_3173_1.RIGHT_CC.LJPEG  4544  3104   LUMISYS
# 3  B_3173_1.RIGHT_MLO.LJPEG  4568  3080   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3174	 ... found the file B-3174-1.ics
#                          fn  rows  cols digitizer
# 0    B_3174_1.LEFT_CC.LJPEG  4608  3136   LUMISYS
# 1   B_3174_1.LEFT_MLO.LJPEG  4592  3120   LUMISYS
# 2   B_3174_1.RIGHT_CC.LJPEG  4560  3104   LUMISYS
# 3  B_3174_1.RIGHT_MLO.LJPEG  4632  3096   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3175	 ... found the file B-3175-1.ics
#                          fn  rows  cols digitizer
# 0    B_3175_1.LEFT_CC.LJPEG  4616  3048   LUMISYS
# 1   B_3175_1.LEFT_MLO.LJPEG  4544  3040   LUMISYS
# 2   B_3175_1.RIGHT_CC.LJPEG  4592  3040   LUMISYS
# 3  B_3175_1.RIGHT_MLO.LJPEG  4568  3032   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3176	 ... found the file B-3176-1.ics
#                          fn  rows  cols digitizer
# 0    B_3176_1.LEFT_CC.LJPEG  4632  2952   LUMISYS
# 1   B_3176_1.LEFT_MLO.LJPEG  4520  3056   LUMISYS
# 2   B_3176_1.RIGHT_CC.LJPEG  4552  3040   LUMISYS
# 3  B_3176_1.RIGHT_MLO.LJPEG  4536  3088   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3177	 ... found the file B-3177-1.ics
#                          fn  rows  cols digitizer
# 0    B_3177_1.LEFT_CC.LJPEG  5640  3976   LUMISYS
# 1   B_3177_1.LEFT_MLO.LJPEG  5592  4064   LUMISYS
# 2   B_3177_1.RIGHT_CC.LJPEG  5800  4104   LUMISYS
# 3  B_3177_1.RIGHT_MLO.LJPEG  5760  4120   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3178	 ... found the file B-3178-1.ics
#                          fn  rows  cols digitizer
# 0    B_3178_1.LEFT_CC.LJPEG  4600  3096   LUMISYS
# 1   B_3178_1.LEFT_MLO.LJPEG  4592  3144   LUMISYS
# 2   B_3178_1.RIGHT_CC.LJPEG  4560  3080   LUMISYS
# 3  B_3178_1.RIGHT_MLO.LJPEG  4592  3128   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3179	 ... found the file B-3179-1.ics
#                          fn  rows  cols digitizer
# 0    B_3179_1.LEFT_CC.LJPEG  5752  4016   LUMISYS
# 1   B_3179_1.LEFT_MLO.LJPEG  5720  4080   LUMISYS
# 2   B_3179_1.RIGHT_CC.LJPEG  5736  4064   LUMISYS
# 3  B_3179_1.RIGHT_MLO.LJPEG  6220  5183   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3180	 ... found the file B-3180-1.ics
#                          fn  rows  cols digitizer
# 0    B_3180_1.LEFT_CC.LJPEG  4616  3128   LUMISYS
# 1   B_3180_1.LEFT_MLO.LJPEG  4608  3112   LUMISYS
# 2   B_3180_1.RIGHT_CC.LJPEG  4624  3104   LUMISYS
# 3  B_3180_1.RIGHT_MLO.LJPEG  4640  3112   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3181	 ... found the file B-3181-1.ics
#                          fn  rows  cols digitizer
# 0    B_3181_1.LEFT_CC.LJPEG  4600  3048   LUMISYS
# 1   B_3181_1.LEFT_MLO.LJPEG  4568  3024   LUMISYS
# 2   B_3181_1.RIGHT_CC.LJPEG  4568  3072   LUMISYS
# 3  B_3181_1.RIGHT_MLO.LJPEG  4592  3056   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3182	 ... found the file B-3182-1.ics
#                          fn  rows  cols digitizer
# 0    B_3182_1.LEFT_CC.LJPEG  4528  3032   LUMISYS
# 1   B_3182_1.LEFT_MLO.LJPEG  4472  2760   LUMISYS
# 2   B_3182_1.RIGHT_CC.LJPEG  4616  3040   LUMISYS
# 3  B_3182_1.RIGHT_MLO.LJPEG  4576  3016   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3183	 ... found the file B-3183-1.ics
#                          fn  rows  cols digitizer
# 0    B_3183_1.LEFT_CC.LJPEG  4552  3072   LUMISYS
# 1   B_3183_1.LEFT_MLO.LJPEG  4512  3024   LUMISYS
# 2   B_3183_1.RIGHT_CC.LJPEG  4624  3064   LUMISYS
# 3  B_3183_1.RIGHT_MLO.LJPEG  4488  3056   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3184	 ... found the file B-3184-1.ics
#                          fn  rows  cols digitizer
# 0    B_3184_1.LEFT_CC.LJPEG  4608  3184   LUMISYS
# 1   B_3184_1.LEFT_MLO.LJPEG  4592  3104   LUMISYS
# 2   B_3184_1.RIGHT_CC.LJPEG  4536  3120   LUMISYS
# 3  B_3184_1.RIGHT_MLO.LJPEG  4600  3112   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3185	 ... found the file B-3185-1.ics
#                          fn  rows  cols digitizer
# 0    B_3185_1.LEFT_CC.LJPEG  4552  3056   LUMISYS
# 1   B_3185_1.LEFT_MLO.LJPEG  4520  3032   LUMISYS
# 2   B_3185_1.RIGHT_CC.LJPEG  4592  3056   LUMISYS
# 3  B_3185_1.RIGHT_MLO.LJPEG  4568  3040   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3186	 ... found the file B-3186-1.ics
#                          fn  rows  cols digitizer
# 0    B_3186_1.LEFT_CC.LJPEG  5440  4000   LUMISYS
# 1   B_3186_1.LEFT_MLO.LJPEG  5464  4096   LUMISYS
# 2   B_3186_1.RIGHT_CC.LJPEG  5720  3992   LUMISYS
# 3  B_3186_1.RIGHT_MLO.LJPEG  5720  4040   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3187	 ... found the file B-3187-1.ics
#                          fn  rows  cols digitizer
# 0    B_3187_1.LEFT_CC.LJPEG  4440  3224   LUMISYS
# 1   B_3187_1.LEFT_MLO.LJPEG  4560  3120   LUMISYS
# 2   B_3187_1.RIGHT_CC.LJPEG  4608  3088   LUMISYS
# 3  B_3187_1.RIGHT_MLO.LJPEG  4216  3040   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3188	 ... found the file B-3188-1.ics
#                          fn  rows  cols digitizer
# 0    B_3188_1.LEFT_CC.LJPEG  5744  3920   LUMISYS
# 1   B_3188_1.LEFT_MLO.LJPEG  5704  4024   LUMISYS
# 2   B_3188_1.RIGHT_CC.LJPEG  5752  3928   LUMISYS
# 3  B_3188_1.RIGHT_MLO.LJPEG  5768  3992   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3189	 ... found the file B-3189-1.ics
#                          fn  rows  cols digitizer
# 0    B_3189_1.LEFT_CC.LJPEG  4560  3104   LUMISYS
# 1   B_3189_1.LEFT_MLO.LJPEG  4384  3112   LUMISYS
# 2   B_3189_1.RIGHT_CC.LJPEG  4576  3120   LUMISYS
# 3  B_3189_1.RIGHT_MLO.LJPEG  4616  3112   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3190	 ... found the file B-3190-1.ics
#                          fn  rows  cols digitizer
# 0    B_3190_1.LEFT_CC.LJPEG  4560  3008   LUMISYS
# 1   B_3190_1.LEFT_MLO.LJPEG  4560  3040   LUMISYS
# 2   B_3190_1.RIGHT_CC.LJPEG  4448  3008   LUMISYS
# 3  B_3190_1.RIGHT_MLO.LJPEG  4568  3056   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3191	 ... found the file B-3191-1.ics
#                          fn  rows  cols digitizer
# 0    B_3191_1.LEFT_CC.LJPEG  4560  3040   LUMISYS
# 1   B_3191_1.LEFT_MLO.LJPEG  4552  3032   LUMISYS
# 2   B_3191_1.RIGHT_CC.LJPEG  4584  3056   LUMISYS
# 3  B_3191_1.RIGHT_MLO.LJPEG  3944  3032   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3205	 ... found the file B-3205-1.ics
#                          fn  rows  cols digitizer
# 0    B_3205_1.LEFT_CC.LJPEG  4616  3088   LUMISYS
# 1   B_3205_1.LEFT_MLO.LJPEG  4576  3080   LUMISYS
# 2   B_3205_1.RIGHT_CC.LJPEG  4600  3056   LUMISYS
# 3  B_3205_1.RIGHT_MLO.LJPEG  4600  3040   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3207	 ... found the file B-3207-1.ics
#                          fn  rows  cols digitizer
# 0    B_3207_1.LEFT_CC.LJPEG  4608  3088   LUMISYS
# 1   B_3207_1.LEFT_MLO.LJPEG  4512  3072   LUMISYS
# 2   B_3207_1.RIGHT_CC.LJPEG  4616  3128   LUMISYS
# 3  B_3207_1.RIGHT_MLO.LJPEG  4696  3136   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3208	 ... found the file B-3208-1.ics
#                          fn  rows  cols digitizer
# 0    B_3208_1.LEFT_CC.LJPEG  4632  3096   LUMISYS
# 1   B_3208_1.LEFT_MLO.LJPEG  4616  3120   LUMISYS
# 2   B_3208_1.RIGHT_CC.LJPEG  4608  3112   LUMISYS
# 3  B_3208_1.RIGHT_MLO.LJPEG  4624  3104   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3210	 ... found the file B-3210-1.ics
#                          fn  rows  cols digitizer
# 0    B_3210_1.LEFT_CC.LJPEG  4616  3080   LUMISYS
# 1   B_3210_1.LEFT_MLO.LJPEG  4584  3064   LUMISYS
# 2   B_3210_1.RIGHT_CC.LJPEG  4632  2984   LUMISYS
# 3  B_3210_1.RIGHT_MLO.LJPEG  4672  3096   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3211	 ... found the file B-3211-1.ics
#                          fn  rows  cols digitizer
# 0    B_3211_1.LEFT_CC.LJPEG  5696  4008   LUMISYS
# 1   B_3211_1.LEFT_MLO.LJPEG  5152  4152   LUMISYS
# 2   B_3211_1.RIGHT_CC.LJPEG  5696  4088   LUMISYS
# 3  B_3211_1.RIGHT_MLO.LJPEG  5712  4080   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3212	 ... found the file B-3212-1.ics
#                          fn  rows  cols digitizer
# 0    B_3212_1.LEFT_CC.LJPEG  5744  4040   LUMISYS
# 1   B_3212_1.LEFT_MLO.LJPEG  5720  4136   LUMISYS
# 2   B_3212_1.RIGHT_CC.LJPEG  5704  4128   LUMISYS
# 3  B_3212_1.RIGHT_MLO.LJPEG  5800  4192   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3213	 ... found the file B-3213-1.ics
#                          fn  rows  cols digitizer
# 0    B_3213_1.LEFT_CC.LJPEG  5688  3856   LUMISYS
# 1   B_3213_1.LEFT_MLO.LJPEG  5640  4008   LUMISYS
# 2   B_3213_1.RIGHT_CC.LJPEG  5712  3936   LUMISYS
# 3  B_3213_1.RIGHT_MLO.LJPEG  5568  4024   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3214	 ... found the file B-3214-1.ics
#                          fn  rows  cols digitizer
# 0    B_3214_1.LEFT_CC.LJPEG  4608  3120   LUMISYS
# 1   B_3214_1.LEFT_MLO.LJPEG  4480  3088   LUMISYS
# 2   B_3214_1.RIGHT_CC.LJPEG  4560  3104   LUMISYS
# 3  B_3214_1.RIGHT_MLO.LJPEG  4528  3112   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3215	 ... found the file B-3215-1.ics
#                          fn  rows  cols digitizer
# 0    B_3215_1.LEFT_CC.LJPEG  4616  3112   LUMISYS
# 1   B_3215_1.LEFT_MLO.LJPEG  4600  3128   LUMISYS
# 2   B_3215_1.RIGHT_CC.LJPEG  4536  3096   LUMISYS
# 3  B_3215_1.RIGHT_MLO.LJPEG  4568  3120   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3216	 ... found the file B-3216-1.ics
#                          fn  rows  cols digitizer
# 0    B_3216_1.LEFT_CC.LJPEG  4672  3080   LUMISYS
# 1   B_3216_1.LEFT_MLO.LJPEG  4536  3072   LUMISYS
# 2   B_3216_1.RIGHT_CC.LJPEG  4648  3112   LUMISYS
# 3  B_3216_1.RIGHT_MLO.LJPEG  4560  3056   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3217	 ... found the file B-3217-1.ics
#                          fn  rows  cols digitizer
# 0    B_3217_1.LEFT_CC.LJPEG  4584  3096   LUMISYS
# 1   B_3217_1.LEFT_MLO.LJPEG  4552  3208   LUMISYS
# 2   B_3217_1.RIGHT_CC.LJPEG  4560  3200   LUMISYS
# 3  B_3217_1.RIGHT_MLO.LJPEG  4616  3360   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3220	 ... found the file B-3220-1.ics
#                          fn  rows  cols digitizer
# 0    B_3220_1.LEFT_CC.LJPEG  4632  2992   LUMISYS
# 1   B_3220_1.LEFT_MLO.LJPEG  4464  3104   LUMISYS
# 2   B_3220_1.RIGHT_CC.LJPEG  4592  3088   LUMISYS
# 3  B_3220_1.RIGHT_MLO.LJPEG  4600  3104   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3222	 ... found the file B-3222-1.ics
#                          fn  rows  cols digitizer
# 0    B_3222_1.LEFT_CC.LJPEG  4384  2488   LUMISYS
# 1   B_3222_1.LEFT_MLO.LJPEG  4528  3048   LUMISYS
# 2   B_3222_1.RIGHT_CC.LJPEG  4608  3048   LUMISYS
# 3  B_3222_1.RIGHT_MLO.LJPEG  4600  3040   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3223	 ... found the file B-3223-1.ics
#                          fn  rows  cols digitizer
# 0    B_3223_1.LEFT_CC.LJPEG  5112  4000   LUMISYS
# 1   B_3223_1.LEFT_MLO.LJPEG  5144  4024   LUMISYS
# 2   B_3223_1.RIGHT_CC.LJPEG  5768  3968   LUMISYS
# 3  B_3223_1.RIGHT_MLO.LJPEG  5768  4032   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3225	 ... found the file B-3225-1.ics
#                          fn  rows  cols digitizer
# 0    B_3225_1.LEFT_CC.LJPEG  4496  3136   LUMISYS
# 1   B_3225_1.LEFT_MLO.LJPEG  4536  3088   LUMISYS
# 2   B_3225_1.RIGHT_CC.LJPEG  4624  3104   LUMISYS
# 3  B_3225_1.RIGHT_MLO.LJPEG  4592  3096   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3227	 ... found the file B-3227-1.ics
#                          fn  rows  cols digitizer
# 0    B_3227_1.LEFT_CC.LJPEG  4592  3104   LUMISYS
# 1   B_3227_1.LEFT_MLO.LJPEG  4480  3128   LUMISYS
# 2   B_3227_1.RIGHT_CC.LJPEG  4632  3104   LUMISYS
# 3  B_3227_1.RIGHT_MLO.LJPEG  4600  3096   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3228	 ... found the file B-3228-1.ics
#                          fn  rows  cols digitizer
# 0    B_3228_1.LEFT_CC.LJPEG  5464  4016   LUMISYS
# 1   B_3228_1.LEFT_MLO.LJPEG  5744  3992   LUMISYS
# 2   B_3228_1.RIGHT_CC.LJPEG  5456  3936   LUMISYS
# 3  B_3228_1.RIGHT_MLO.LJPEG  5336  3720   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3229	 ... found the file B-3229-1.ics
#                          fn  rows  cols digitizer
# 0    B_3229_1.LEFT_CC.LJPEG  4600  3088   LUMISYS
# 1   B_3229_1.LEFT_MLO.LJPEG  4536  3088   LUMISYS
# 2   B_3229_1.RIGHT_CC.LJPEG  4576  3104   LUMISYS
# 3  B_3229_1.RIGHT_MLO.LJPEG  4600  3096   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3230	 ... found the file B-3230-1.ics
#                          fn  rows  cols digitizer
# 0    B_3230_1.LEFT_CC.LJPEG  4480  3032   LUMISYS
# 1   B_3230_1.LEFT_MLO.LJPEG  4496  3040   LUMISYS
# 2   B_3230_1.RIGHT_CC.LJPEG  4576  3016   LUMISYS
# 3  B_3230_1.RIGHT_MLO.LJPEG  4488  3024   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3231	 ... found the file B-3231-1.ics
#                          fn  rows  cols digitizer
# 0    B_3231_1.LEFT_CC.LJPEG  4616  3064   LUMISYS
# 1   B_3231_1.LEFT_MLO.LJPEG  4584  3080   LUMISYS
# 2   B_3231_1.RIGHT_CC.LJPEG  4672  3120   LUMISYS
# 3  B_3231_1.RIGHT_MLO.LJPEG  4592  3072   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3232	 ... found the file B-3232-1.ics
#                          fn  rows  cols digitizer
# 0    B_3232_1.LEFT_CC.LJPEG  4584  3096   LUMISYS
# 1   B_3232_1.LEFT_MLO.LJPEG  4544  3096   LUMISYS
# 2   B_3232_1.RIGHT_CC.LJPEG  4528  3120   LUMISYS
# 3  B_3232_1.RIGHT_MLO.LJPEG  4464  3104   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3233	 ... found the file B-3233-1.ics
#                          fn  rows  cols digitizer
# 0    B_3233_1.LEFT_CC.LJPEG  5464  3768   LUMISYS
# 1   B_3233_1.LEFT_MLO.LJPEG  5496  3872   LUMISYS
# 2   B_3233_1.RIGHT_CC.LJPEG  5440  3832   LUMISYS
# 3  B_3233_1.RIGHT_MLO.LJPEG  5600  3888   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3234	 ... found the file B-3234-1.ics
#                          fn  rows  cols digitizer
# 0    B_3234_1.LEFT_CC.LJPEG  4496  3096   LUMISYS
# 1   B_3234_1.LEFT_MLO.LJPEG  4496  3088   LUMISYS
# 2   B_3234_1.RIGHT_CC.LJPEG  4272  3104   LUMISYS
# 3  B_3234_1.RIGHT_MLO.LJPEG  4424  3120   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3235	 ... found the file B-3235-1.ics
#                          fn  rows  cols digitizer
# 0    B_3235_1.LEFT_CC.LJPEG  5680  4096   LUMISYS
# 1   B_3235_1.LEFT_MLO.LJPEG  5664  4032   LUMISYS
# 2   B_3235_1.RIGHT_CC.LJPEG  5528  4112   LUMISYS
# 3  B_3235_1.RIGHT_MLO.LJPEG  5576  4072   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3237	 ... found the file B-3237-1.ics
#                          fn  rows  cols digitizer
# 0    B_3237_1.LEFT_CC.LJPEG  4328  3024   LUMISYS
# 1   B_3237_1.LEFT_MLO.LJPEG  4456  3024   LUMISYS
# 2   B_3237_1.RIGHT_CC.LJPEG  4424  2936   LUMISYS
# 3  B_3237_1.RIGHT_MLO.LJPEG  4448  3048   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3238	 ... found the file B-3238-1.ics
#                          fn  rows  cols digitizer
# 0    B_3238_1.LEFT_CC.LJPEG  4424  3080   LUMISYS
# 1   B_3238_1.LEFT_MLO.LJPEG  4448  2944   LUMISYS
# 2   B_3238_1.RIGHT_CC.LJPEG  4232  3048   LUMISYS
# 3  B_3238_1.RIGHT_MLO.LJPEG  4496  3056   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3239	 ... found the file B-3239-1.ics
#                          fn  rows  cols digitizer
# 0    B_3239_1.LEFT_CC.LJPEG  5616  4016   LUMISYS
# 1   B_3239_1.LEFT_MLO.LJPEG  5672  4064   LUMISYS
# 2   B_3239_1.RIGHT_CC.LJPEG  5672  3960   LUMISYS
# 3  B_3239_1.RIGHT_MLO.LJPEG  5624  3952   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3240	 ... found the file B-3240-1.ics
#                          fn  rows  cols digitizer
# 0    B_3240_1.LEFT_CC.LJPEG  5720  4040   LUMISYS
# 1   B_3240_1.LEFT_MLO.LJPEG  5680  4168   LUMISYS
# 2   B_3240_1.RIGHT_CC.LJPEG  5696  4008   LUMISYS
# 3  B_3240_1.RIGHT_MLO.LJPEG  5800  4064   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3241	 ... found the file B-3241-1.ics
#                          fn  rows  cols digitizer
# 0    B_3241_1.LEFT_CC.LJPEG  5720  4088   LUMISYS
# 1   B_3241_1.LEFT_MLO.LJPEG  5840  3888   LUMISYS
# 2   B_3241_1.RIGHT_CC.LJPEG  5744  4088   LUMISYS
# 3  B_3241_1.RIGHT_MLO.LJPEG  5704  4128   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3242	 ... found the file B-3242-1.ics
#                          fn  rows  cols digitizer
# 0    B_3242_1.LEFT_CC.LJPEG  4544  3104   LUMISYS
# 1   B_3242_1.LEFT_MLO.LJPEG  4600  3016   LUMISYS
# 2   B_3242_1.RIGHT_CC.LJPEG  4392  3104   LUMISYS
# 3  B_3242_1.RIGHT_MLO.LJPEG  4488  3080   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3243	 ... found the file B-3243-1.ics
#                          fn  rows  cols digitizer
# 0    B_3243_1.LEFT_CC.LJPEG  4560  3120   LUMISYS
# 1   B_3243_1.LEFT_MLO.LJPEG  4528  3192   LUMISYS
# 2   B_3243_1.RIGHT_CC.LJPEG  4528  3080   LUMISYS
# 3  B_3243_1.RIGHT_MLO.LJPEG  4480  3064   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3244	 ... found the file B-3244-1.ics
#                          fn  rows  cols digitizer
# 0    B_3244_1.LEFT_CC.LJPEG  4584  3072   LUMISYS
# 1   B_3244_1.LEFT_MLO.LJPEG  4440  3072   LUMISYS
# 2   B_3244_1.RIGHT_CC.LJPEG  4400  3104   LUMISYS
# 3  B_3244_1.RIGHT_MLO.LJPEG  4496  3072   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3245	 ... found the file B-3245-1.ics
#                          fn  rows  cols digitizer
# 0    B_3245_1.LEFT_CC.LJPEG  4424  3064   LUMISYS
# 1   B_3245_1.LEFT_MLO.LJPEG  4640  3280   LUMISYS
# 2   B_3245_1.RIGHT_CC.LJPEG  4392  3016   LUMISYS
# 3  B_3245_1.RIGHT_MLO.LJPEG  4432  2992   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3246	 ... found the file B-3246-1.ics
#                          fn  rows  cols digitizer
# 0    B_3246_1.LEFT_CC.LJPEG  4464  3024   LUMISYS
# 1   B_3246_1.LEFT_MLO.LJPEG  4480  3016   LUMISYS
# 2   B_3246_1.RIGHT_CC.LJPEG  4416  2992   LUMISYS
# 3  B_3246_1.RIGHT_MLO.LJPEG  4424  3024   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3247	 ... found the file B-3247-1.ics
#                          fn  rows  cols digitizer
# 0    B_3247_1.LEFT_CC.LJPEG  4592  3016   LUMISYS
# 1   B_3247_1.LEFT_MLO.LJPEG  4560  3000   LUMISYS
# 2   B_3247_1.RIGHT_CC.LJPEG  4424  3040   LUMISYS
# 3  B_3247_1.RIGHT_MLO.LJPEG  4488  3032   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3248	 ... found the file B-3248-1.ics
#                          fn  rows  cols digitizer
# 0    B_3248_1.LEFT_CC.LJPEG  4264  2976   LUMISYS
# 1   B_3248_1.LEFT_MLO.LJPEG  4312  3040   LUMISYS
# 2   B_3248_1.RIGHT_CC.LJPEG  4352  3008   LUMISYS
# 3  B_3248_1.RIGHT_MLO.LJPEG  4384  2976   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3250	 ... found the file B-3250-1.ics
#                          fn  rows  cols digitizer
# 0    B_3250_1.LEFT_CC.LJPEG  4552  3032   LUMISYS
# 1   B_3250_1.LEFT_MLO.LJPEG  4560  3064   LUMISYS
# 2   B_3250_1.RIGHT_CC.LJPEG  4568  3080   LUMISYS
# 3  B_3250_1.RIGHT_MLO.LJPEG  4608  3056   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3251	 ... found the file B-3251-1.ics
#                          fn  rows  cols digitizer
# 0    B_3251_1.LEFT_CC.LJPEG  4464  3056   LUMISYS
# 1   B_3251_1.LEFT_MLO.LJPEG  4184  3024   LUMISYS
# 2   B_3251_1.RIGHT_CC.LJPEG  4416  3016   LUMISYS
# 3  B_3251_1.RIGHT_MLO.LJPEG  4240  3024   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3252	 ... found the file B-3252-1.ics
#                          fn  rows  cols digitizer
# 0    B_3252_1.LEFT_CC.LJPEG  4536  3080   LUMISYS
# 1   B_3252_1.LEFT_MLO.LJPEG  4464  3056   LUMISYS
# 2   B_3252_1.RIGHT_CC.LJPEG  4480  3008   LUMISYS
# 3  B_3252_1.RIGHT_MLO.LJPEG  4440  3000   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3253	 ... found the file B-3253-1.ics
#                          fn  rows  cols digitizer
# 0    B_3253_1.LEFT_CC.LJPEG  5592  4056   LUMISYS
# 1   B_3253_1.LEFT_MLO.LJPEG  5632  4160   LUMISYS
# 2   B_3253_1.RIGHT_CC.LJPEG  5576  4176   LUMISYS
# 3  B_3253_1.RIGHT_MLO.LJPEG  5728  4120   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3254	 ... found the file B-3254-1.ics
#                          fn  rows  cols digitizer
# 0    B_3254_1.LEFT_CC.LJPEG  4632  3088   LUMISYS
# 1   B_3254_1.LEFT_MLO.LJPEG  4632  3064   LUMISYS
# 2   B_3254_1.RIGHT_CC.LJPEG  4600  3096   LUMISYS
# 3  B_3254_1.RIGHT_MLO.LJPEG  4608  3088   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_01/case3255	 ... found the file B-3255-1.ics
#                          fn  rows  cols digitizer
# 0    B_3255_1.LEFT_CC.LJPEG  5232  3888   LUMISYS
# 1   B_3255_1.LEFT_MLO.LJPEG  5240  3912   LUMISYS
# 2   B_3255_1.RIGHT_CC.LJPEG  5224  3744   LUMISYS
# 3  B_3255_1.RIGHT_MLO.LJPEG  5128  3624   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0419	 ... found the file C-0419-1.ics
#                          fn  rows  cols digitizer
# 0    C_0419_1.LEFT_CC.LJPEG  4544  2936   LUMISYS
# 1   C_0419_1.LEFT_MLO.LJPEG  4576  2904   LUMISYS
# 2   C_0419_1.RIGHT_CC.LJPEG  4552  2912   LUMISYS
# 3  C_0419_1.RIGHT_MLO.LJPEG  4560  2888   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0420	 ... found the file C-0420-1.ics
#                          fn  rows  cols digitizer
# 0    C_0420_1.LEFT_CC.LJPEG  4552  2976   LUMISYS
# 1   C_0420_1.LEFT_MLO.LJPEG  4568  2928   LUMISYS
# 2   C_0420_1.RIGHT_CC.LJPEG  4592  2888   LUMISYS
# 3  C_0420_1.RIGHT_MLO.LJPEG  4520  2888   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0421	 ... found the file C-0421-1.ics
#                          fn  rows  cols digitizer
# 0    C_0421_1.LEFT_CC.LJPEG  5536  3944   LUMISYS
# 1   C_0421_1.LEFT_MLO.LJPEG  5560  3936   LUMISYS
# 2   C_0421_1.RIGHT_CC.LJPEG  5688  3968   LUMISYS
# 3  C_0421_1.RIGHT_MLO.LJPEG  5664  3960   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0422	 ... found the file C-0422-1.ics
#                          fn  rows  cols digitizer
# 0    C_0422_1.LEFT_CC.LJPEG  4552  2864   LUMISYS
# 1   C_0422_1.LEFT_MLO.LJPEG  4544  2840   LUMISYS
# 2   C_0422_1.RIGHT_CC.LJPEG  4536  2896   LUMISYS
# 3  C_0422_1.RIGHT_MLO.LJPEG  4576  2880   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0423	 ... found the file C-0423-1.ics
#                          fn  rows  cols digitizer
# 0    C_0423_1.LEFT_CC.LJPEG  4568  2992   LUMISYS
# 1   C_0423_1.LEFT_MLO.LJPEG  4608  2976   LUMISYS
# 2   C_0423_1.RIGHT_CC.LJPEG  4592  2976   LUMISYS
# 3  C_0423_1.RIGHT_MLO.LJPEG  4560  2832   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0424	 ... found the file C-0424-1.ics
#                          fn  rows  cols digitizer
# 0    C_0424_1.LEFT_CC.LJPEG  4456  2960   LUMISYS
# 1   C_0424_1.LEFT_MLO.LJPEG  4544  2976   LUMISYS
# 2   C_0424_1.RIGHT_CC.LJPEG  4504  2968   LUMISYS
# 3  C_0424_1.RIGHT_MLO.LJPEG  4552  2944   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0425	 ... found the file C-0425-1.ics
#                          fn  rows  cols digitizer
# 0    C_0425_1.LEFT_CC.LJPEG  4536  2928   LUMISYS
# 1   C_0425_1.LEFT_MLO.LJPEG  4432  2920   LUMISYS
# 2   C_0425_1.RIGHT_CC.LJPEG  4552  2928   LUMISYS
# 3  C_0425_1.RIGHT_MLO.LJPEG  4592  2920   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0426	 ... found the file C-0426-1.ics
#                          fn  rows  cols digitizer
# 0    C_0426_1.LEFT_CC.LJPEG  4472  2944   LUMISYS
# 1   C_0426_1.LEFT_MLO.LJPEG  4512  3008   LUMISYS
# 2   C_0426_1.RIGHT_CC.LJPEG  4528  3000   LUMISYS
# 3  C_0426_1.RIGHT_MLO.LJPEG  4544  2944   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0427	 ... found the file C-0427-1.ics
#                          fn  rows  cols digitizer
# 0    C_0427_1.LEFT_CC.LJPEG  5592  3920   LUMISYS
# 1   C_0427_1.LEFT_MLO.LJPEG  5624  3848   LUMISYS
# 2   C_0427_1.RIGHT_CC.LJPEG  5704  3952   LUMISYS
# 3  C_0427_1.RIGHT_MLO.LJPEG  5608  3872   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0428	 ... found the file C-0428-1.ics
#                          fn  rows  cols digitizer
# 0    C_0428_1.LEFT_CC.LJPEG  5752  4056   LUMISYS
# 1   C_0428_1.LEFT_MLO.LJPEG  5680  4016   LUMISYS
# 2   C_0428_1.RIGHT_CC.LJPEG  5632  4056   LUMISYS
# 3  C_0428_1.RIGHT_MLO.LJPEG  5688  4056   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0430	 ... found the file C-0430-1.ics
#                          fn  rows  cols digitizer
# 0    C_0430_1.LEFT_CC.LJPEG  4560  2920   LUMISYS
# 1   C_0430_1.LEFT_MLO.LJPEG  4560  2896   LUMISYS
# 2   C_0430_1.RIGHT_CC.LJPEG  4600  2936   LUMISYS
# 3  C_0430_1.RIGHT_MLO.LJPEG  4560  2896   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0431	 ... found the file C-0431-1.ics
#                          fn  rows  cols digitizer
# 0    C_0431_1.LEFT_CC.LJPEG  4512  2888   LUMISYS
# 1   C_0431_1.LEFT_MLO.LJPEG  4512  2912   LUMISYS
# 2   C_0431_1.RIGHT_CC.LJPEG  4552  2872   LUMISYS
# 3  C_0431_1.RIGHT_MLO.LJPEG  4520  2920   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0432	 ... found the file C-0432-1.ics
#                          fn  rows  cols digitizer
# 0    C_0432_1.LEFT_CC.LJPEG  4464  2920   LUMISYS
# 1   C_0432_1.LEFT_MLO.LJPEG  4520  3024   LUMISYS
# 2   C_0432_1.RIGHT_CC.LJPEG  4544  2936   LUMISYS
# 3  C_0432_1.RIGHT_MLO.LJPEG  4536  2952   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0434	 ... found the file C-0434-1.ics
#                          fn  rows  cols digitizer
# 0    C_0434_1.LEFT_CC.LJPEG  4528  2976   LUMISYS
# 1   C_0434_1.LEFT_MLO.LJPEG  4552  2976   LUMISYS
# 2   C_0434_1.RIGHT_CC.LJPEG  4584  2944   LUMISYS
# 3  C_0434_1.RIGHT_MLO.LJPEG  4568  2944   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0435	 ... found the file C-0435-1.ics
#                          fn  rows  cols digitizer
# 0    C_0435_1.LEFT_CC.LJPEG  4600  2944   LUMISYS
# 1   C_0435_1.LEFT_MLO.LJPEG  4408  2968   LUMISYS
# 2   C_0435_1.RIGHT_CC.LJPEG  4616  2936   LUMISYS
# 3  C_0435_1.RIGHT_MLO.LJPEG  4608  2888   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0436	 ... found the file C-0436-1.ics
#                          fn  rows  cols digitizer
# 0    C_0436_1.LEFT_CC.LJPEG  4560  2896   LUMISYS
# 1   C_0436_1.LEFT_MLO.LJPEG  4456  3000   LUMISYS
# 2   C_0436_1.RIGHT_CC.LJPEG  4568  2872   LUMISYS
# 3  C_0436_1.RIGHT_MLO.LJPEG  4584  2952   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0437	 ... found the file C-0437-1.ics
#                          fn  rows  cols digitizer
# 0    C_0437_1.LEFT_CC.LJPEG  4464  2888   LUMISYS
# 1   C_0437_1.LEFT_MLO.LJPEG  4560  3032   LUMISYS
# 2   C_0437_1.RIGHT_CC.LJPEG  4584  2864   LUMISYS
# 3  C_0437_1.RIGHT_MLO.LJPEG  4560  2880   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0438	 ... found the file C-0438-1.ics
#                          fn  rows  cols digitizer
# 0    C_0438_1.LEFT_CC.LJPEG  4600  2888   LUMISYS
# 1   C_0438_1.LEFT_MLO.LJPEG  4512  2888   LUMISYS
# 2   C_0438_1.RIGHT_CC.LJPEG  4544  2912   LUMISYS
# 3  C_0438_1.RIGHT_MLO.LJPEG  4504  2896   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0439	 ... found the file C-0439-1.ics
#                          fn  rows  cols digitizer
# 0    C_0439_1.LEFT_CC.LJPEG  5568  3648   LUMISYS
# 1   C_0439_1.LEFT_MLO.LJPEG  5672  4016   LUMISYS
# 2   C_0439_1.RIGHT_CC.LJPEG  5696  3800   LUMISYS
# 3  C_0439_1.RIGHT_MLO.LJPEG  5704  3912   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0440	 ... found the file C-0440-1.ics
#                          fn  rows  cols digitizer
# 0    C_0440_1.LEFT_CC.LJPEG  4584  2912   LUMISYS
# 1   C_0440_1.LEFT_MLO.LJPEG  4592  2880   LUMISYS
# 2   C_0440_1.RIGHT_CC.LJPEG  4552  2920   LUMISYS
# 3  C_0440_1.RIGHT_MLO.LJPEG  4584  2888   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0441	 ... found the file C-0441-1.ics
#                          fn  rows  cols digitizer
# 0    C_0441_1.LEFT_CC.LJPEG  4560  2944   LUMISYS
# 1   C_0441_1.LEFT_MLO.LJPEG  4528  2888   LUMISYS
# 2   C_0441_1.RIGHT_CC.LJPEG  4552  2928   LUMISYS
# 3  C_0441_1.RIGHT_MLO.LJPEG  4592  2896   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0442	 ... found the file C-0442-1.ics
#                          fn  rows  cols digitizer
# 0    C_0442_1.LEFT_CC.LJPEG  4520  2864   LUMISYS
# 1   C_0442_1.LEFT_MLO.LJPEG  4464  2888   LUMISYS
# 2   C_0442_1.RIGHT_CC.LJPEG  4560  2840   LUMISYS
# 3  C_0442_1.RIGHT_MLO.LJPEG  4544  2968   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0443	 ... found the file C-0443-1.ics
#                          fn  rows  cols digitizer
# 0    C_0443_1.LEFT_CC.LJPEG  4624  2896   LUMISYS
# 1   C_0443_1.LEFT_MLO.LJPEG  4536  2872   LUMISYS
# 2   C_0443_1.RIGHT_CC.LJPEG  4576  2880   LUMISYS
# 3  C_0443_1.RIGHT_MLO.LJPEG  4528  2912   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0444	 ... found the file C-0444-1.ics
#                          fn  rows  cols digitizer
# 0    C_0444_1.LEFT_CC.LJPEG  4552  2888   LUMISYS
# 1   C_0444_1.LEFT_MLO.LJPEG  4568  2928   LUMISYS
# 2   C_0444_1.RIGHT_CC.LJPEG  4584  2912   LUMISYS
# 3  C_0444_1.RIGHT_MLO.LJPEG  4576  2872   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0445	 ... found the file C-0445-1.ics
#                          fn  rows  cols digitizer
# 0    C_0445_1.LEFT_CC.LJPEG  4576  2968   LUMISYS
# 1   C_0445_1.LEFT_MLO.LJPEG  4584  2952   LUMISYS
# 2   C_0445_1.RIGHT_CC.LJPEG  4440  2984   LUMISYS
# 3  C_0445_1.RIGHT_MLO.LJPEG  4552  2904   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0446	 ... found the file C-0446-1.ics
#                          fn  rows  cols digitizer
# 0    C_0446_1.LEFT_CC.LJPEG  5720  3944   LUMISYS
# 1   C_0446_1.LEFT_MLO.LJPEG  5680  3992   LUMISYS
# 2   C_0446_1.RIGHT_CC.LJPEG  5600  3672   LUMISYS
# 3  C_0446_1.RIGHT_MLO.LJPEG  5728  3712   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0447	 ... found the file C-0447-1.ics
#                          fn  rows  cols digitizer
# 0    C_0447_1.LEFT_CC.LJPEG  4536  2888   LUMISYS
# 1   C_0447_1.LEFT_MLO.LJPEG  4560  2832   LUMISYS
# 2   C_0447_1.RIGHT_CC.LJPEG  4584  2880   LUMISYS
# 3  C_0447_1.RIGHT_MLO.LJPEG  4544  2888   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0448	 ... found the file C-0448-1.ics
#                          fn  rows  cols digitizer
# 0    C_0448_1.LEFT_CC.LJPEG  4552  2880   LUMISYS
# 1   C_0448_1.LEFT_MLO.LJPEG  4568  2888   LUMISYS
# 2   C_0448_1.RIGHT_CC.LJPEG  4600  2928   LUMISYS
# 3  C_0448_1.RIGHT_MLO.LJPEG  4568  2880   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0449	 ... found the file C-0449-1.ics
#                          fn  rows  cols digitizer
# 0    C_0449_1.LEFT_CC.LJPEG  5776  4104   LUMISYS
# 1   C_0449_1.LEFT_MLO.LJPEG  5768  4120   LUMISYS
# 2   C_0449_1.RIGHT_CC.LJPEG  5728  4048   LUMISYS
# 3  C_0449_1.RIGHT_MLO.LJPEG  5744  4128   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0450	 ... found the file C-0450-1.ics
#                          fn  rows  cols digitizer
# 0    C_0450_1.LEFT_CC.LJPEG  4528  2888   LUMISYS
# 1   C_0450_1.LEFT_MLO.LJPEG  4496  2880   LUMISYS
# 2   C_0450_1.RIGHT_CC.LJPEG  4560  2952   LUMISYS
# 3  C_0450_1.RIGHT_MLO.LJPEG  4560  2896   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0451	 ... found the file C-0451-1.ics
#                          fn  rows  cols digitizer
# 0    C_0451_1.LEFT_CC.LJPEG  4392  2848   LUMISYS
# 1   C_0451_1.LEFT_MLO.LJPEG  4608  2912   LUMISYS
# 2   C_0451_1.RIGHT_CC.LJPEG  4528  2888   LUMISYS
# 3  C_0451_1.RIGHT_MLO.LJPEG  4560  2912   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0452	 ... found the file C-0452-1.ics
#                          fn  rows  cols digitizer
# 0    C_0452_1.LEFT_CC.LJPEG  4536  2968   LUMISYS
# 1   C_0452_1.LEFT_MLO.LJPEG  4472  2984   LUMISYS
# 2   C_0452_1.RIGHT_CC.LJPEG  4576  2904   LUMISYS
# 3  C_0452_1.RIGHT_MLO.LJPEG  4584  2960   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0453	 ... found the file C-0453-1.ics
#                          fn  rows  cols digitizer
# 0    C_0453_1.LEFT_CC.LJPEG  4552  2880   LUMISYS
# 1   C_0453_1.LEFT_MLO.LJPEG  4576  2888   LUMISYS
# 2   C_0453_1.RIGHT_CC.LJPEG  4624  2920   LUMISYS
# 3  C_0453_1.RIGHT_MLO.LJPEG  4632  2904   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0454	 ... found the file C-0454-1.ics
#                          fn  rows  cols digitizer
# 0    C_0454_1.LEFT_CC.LJPEG  4512  2912   LUMISYS
# 1   C_0454_1.LEFT_MLO.LJPEG  4520  2840   LUMISYS
# 2   C_0454_1.RIGHT_CC.LJPEG  4632  2896   LUMISYS
# 3  C_0454_1.RIGHT_MLO.LJPEG  4784  2920   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0455	 ... found the file C-0455-1.ics
#                          fn  rows  cols digitizer
# 0    C_0455_1.LEFT_CC.LJPEG  4648  3000   LUMISYS
# 1   C_0455_1.LEFT_MLO.LJPEG  4592  2984   LUMISYS
# 2   C_0455_1.RIGHT_CC.LJPEG  4624  2920   LUMISYS
# 3  C_0455_1.RIGHT_MLO.LJPEG  4608  2944   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0456	 ... found the file C-0456-1.ics
#                          fn  rows  cols digitizer
# 0    C_0456_1.LEFT_CC.LJPEG  4584  2896   LUMISYS
# 1   C_0456_1.LEFT_MLO.LJPEG  4568  2896   LUMISYS
# 2   C_0456_1.RIGHT_CC.LJPEG  4584  2952   LUMISYS
# 3  C_0456_1.RIGHT_MLO.LJPEG  4552  2936   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0459	 ... found the file C-0459-1.ics
#                          fn  rows  cols digitizer
# 0    C_0459_1.LEFT_CC.LJPEG  5752  4096   LUMISYS
# 1   C_0459_1.LEFT_MLO.LJPEG  5744  4080   LUMISYS
# 2   C_0459_1.RIGHT_CC.LJPEG  5768  4088   LUMISYS
# 3  C_0459_1.RIGHT_MLO.LJPEG  5768  4104   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0460	 ... found the file C-0460-1.ics
#                          fn  rows  cols digitizer
# 0    C_0460_1.LEFT_CC.LJPEG  4528  2936   LUMISYS
# 1   C_0460_1.LEFT_MLO.LJPEG  4584  2944   LUMISYS
# 2   C_0460_1.RIGHT_CC.LJPEG  4616  2936   LUMISYS
# 3  C_0460_1.RIGHT_MLO.LJPEG  4632  2912   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0461	 ... found the file C-0461-1.ics
#                          fn  rows  cols digitizer
# 0    C_0461_1.LEFT_CC.LJPEG  4552  2848   LUMISYS
# 1   C_0461_1.LEFT_MLO.LJPEG  4552  2896   LUMISYS
# 2   C_0461_1.RIGHT_CC.LJPEG  4592  2904   LUMISYS
# 3  C_0461_1.RIGHT_MLO.LJPEG  4616  2888   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0462	 ... found the file C-0462-1.ics
#                          fn  rows  cols digitizer
# 0    C_0462_1.LEFT_CC.LJPEG  4624  2728   LUMISYS
# 1   C_0462_1.LEFT_MLO.LJPEG  4600  2736   LUMISYS
# 2   C_0462_1.RIGHT_CC.LJPEG  4608  2880   LUMISYS
# 3  C_0462_1.RIGHT_MLO.LJPEG  4656  2888   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benign_without_callbacks/benign_without_callback_02/case0463	 ... found the file C-0463-1.ics
#                          fn  rows  cols digitizer
# 0    C_0463_1.LEFT_CC.LJPEG  4496  2768   LUMISYS
# 1   C_0463_1.LEFT_MLO.LJPEG  4560  2856   LUMISYS
# 2   C_0463_1.RIGHT_CC.LJPEG  4592  2912   LUMISYS
# 3  C_0463_1.RIGHT_MLO.LJPEG  4608  2880   LUMISYS
#
# ...
# 3  B_3113_1.RIGHT_MLO.LJPEG  4696  2792   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3114	 ... found the file B-3114-1.ics
#                          fn  rows  cols digitizer
# 0    B_3114_1.LEFT_CC.LJPEG  4720  2792   LUMISYS
# 1   B_3114_1.LEFT_MLO.LJPEG  4744  2912   LUMISYS
# 2   B_3114_1.RIGHT_CC.LJPEG  4688  2616   LUMISYS
# 3  B_3114_1.RIGHT_MLO.LJPEG  4808  2584   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3117	 ... found the file B-3117-1.ics
#                          fn  rows  cols digitizer
# 0    B_3117_1.LEFT_CC.LJPEG  4728  3144   LUMISYS
# 1   B_3117_1.LEFT_MLO.LJPEG  4704  2992   LUMISYS
# 2   B_3117_1.RIGHT_CC.LJPEG  4760  3088   LUMISYS
# 3  B_3117_1.RIGHT_MLO.LJPEG  4784  3016   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3118	 ... found the file B-3118-1.ics
#                          fn  rows  cols digitizer
# 0    B_3118_1.LEFT_CC.LJPEG  4728  2584   LUMISYS
# 1   B_3118_1.LEFT_MLO.LJPEG  4736  2768   LUMISYS
# 2   B_3118_1.RIGHT_CC.LJPEG  4720  2776   LUMISYS
# 3  B_3118_1.RIGHT_MLO.LJPEG  4720  2640   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3119	 ... found the file B-3119-1.ics
#                          fn  rows  cols digitizer
# 0    B_3119_1.LEFT_CC.LJPEG  4736  2344   LUMISYS
# 1   B_3119_1.LEFT_MLO.LJPEG  4696  2696   LUMISYS
# 2   B_3119_1.RIGHT_CC.LJPEG  4648  2496   LUMISYS
# 3  B_3119_1.RIGHT_MLO.LJPEG  4640  2648   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3122	 ... found the file B-3122-1.ics
#                          fn  rows  cols digitizer
# 0    B_3122_1.LEFT_CC.LJPEG  5752  3864   LUMISYS
# 1   B_3122_1.LEFT_MLO.LJPEG  5768  4128   LUMISYS
# 2   B_3122_1.RIGHT_CC.LJPEG  5768  4128   LUMISYS
# 3  B_3122_1.RIGHT_MLO.LJPEG  5832  4168   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3124	 ... found the file B-3124-1.ics
#                          fn  rows  cols digitizer
# 0    B_3124_1.LEFT_CC.LJPEG  4768  2816   LUMISYS
# 1   B_3124_1.LEFT_MLO.LJPEG  4744  2760   LUMISYS
# 2   B_3124_1.RIGHT_CC.LJPEG  4704  2720   LUMISYS
# 3  B_3124_1.RIGHT_MLO.LJPEG  4760  2696   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3125	 ... found the file B-3125-1.ics
#                          fn  rows  cols digitizer
# 0    B_3125_1.LEFT_CC.LJPEG  4688  2712   LUMISYS
# 1   B_3125_1.LEFT_MLO.LJPEG  4704  2640   LUMISYS
# 2   B_3125_1.RIGHT_CC.LJPEG  4768  2640   LUMISYS
# 3  B_3125_1.RIGHT_MLO.LJPEG  4720  2672   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3126	 ... found the file B-3126-1.ics
#                          fn  rows  cols digitizer
# 0    B_3126_1.LEFT_CC.LJPEG  4744  2800   LUMISYS
# 1   B_3126_1.LEFT_MLO.LJPEG  4696  2856   LUMISYS
# 2   B_3126_1.RIGHT_CC.LJPEG  4648  2760   LUMISYS
# 3  B_3126_1.RIGHT_MLO.LJPEG  4712  2752   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3127	 ... found the file B-3127-1.ics
#                          fn  rows  cols digitizer
# 0    B_3127_1.LEFT_CC.LJPEG  4744  2296   LUMISYS
# 1   B_3127_1.LEFT_MLO.LJPEG  4696  2376   LUMISYS
# 2   B_3127_1.RIGHT_CC.LJPEG  4720  2304   LUMISYS
# 3  B_3127_1.RIGHT_MLO.LJPEG  4664  2456   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3128	 ... found the file B-3128-1.ics
#                          fn  rows  cols digitizer
# 0    B_3128_1.LEFT_CC.LJPEG  4816  2464   LUMISYS
# 1   B_3128_1.LEFT_MLO.LJPEG  4800  2696   LUMISYS
# 2   B_3128_1.RIGHT_CC.LJPEG  4792  2664   LUMISYS
# 3  B_3128_1.RIGHT_MLO.LJPEG  4776  2768   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3129	 ... found the file B-3129-1.ics
#                          fn  rows  cols digitizer
# 0    B_3129_1.LEFT_CC.LJPEG  4680  3072   LUMISYS
# 1   B_3129_1.LEFT_MLO.LJPEG  4592  3032   LUMISYS
# 2   B_3129_1.RIGHT_CC.LJPEG  4640  3048   LUMISYS
# 3  B_3129_1.RIGHT_MLO.LJPEG  4632  3040   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3130	 ... found the file B-3130-1.ics
#                          fn  rows  cols digitizer
# 0    B_3130_1.LEFT_CC.LJPEG  4664  2528   LUMISYS
# 1   B_3130_1.LEFT_MLO.LJPEG  4624  2664   LUMISYS
# 2   B_3130_1.RIGHT_CC.LJPEG  4592  2640   LUMISYS
# 3  B_3130_1.RIGHT_MLO.LJPEG  4632  2640   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3131	 ... found the file B-3131-1.ics
#                          fn  rows  cols digitizer
# 0    B_3131_1.LEFT_CC.LJPEG  4712  2632   LUMISYS
# 1   B_3131_1.LEFT_MLO.LJPEG  4672  2768   LUMISYS
# 2   B_3131_1.RIGHT_CC.LJPEG  4704  2568   LUMISYS
# 3  B_3131_1.RIGHT_MLO.LJPEG  4720  2768   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3132	 ... found the file B-3132-1.ics
#                          fn  rows  cols digitizer
# 0    B_3132_1.LEFT_CC.LJPEG  4728  2568   LUMISYS
# 1   B_3132_1.LEFT_MLO.LJPEG  4728  2792   LUMISYS
# 2   B_3132_1.RIGHT_CC.LJPEG  4664  3104   LUMISYS
# 3  B_3132_1.RIGHT_MLO.LJPEG  4664  3136   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3133	 ... found the file B-3133-1.ics
#                          fn  rows  cols digitizer
# 0    B_3133_1.LEFT_CC.LJPEG  4712  2600   LUMISYS
# 1   B_3133_1.LEFT_MLO.LJPEG  4664  2608   LUMISYS
# 2   B_3133_1.RIGHT_CC.LJPEG  4632  2776   LUMISYS
# 3  B_3133_1.RIGHT_MLO.LJPEG  4624  2752   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3140	 ... found the file B-3140-1.ics
#                          fn  rows  cols digitizer
# 0    B_3140_1.LEFT_CC.LJPEG  4688  2552   LUMISYS
# 1   B_3140_1.LEFT_MLO.LJPEG  4760  2920   LUMISYS
# 2   B_3140_1.RIGHT_CC.LJPEG  4704  2840   LUMISYS
# 3  B_3140_1.RIGHT_MLO.LJPEG  4728  2880   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3141	 ... found the file B-3141-1.ics
#                          fn  rows  cols digitizer
# 0    B_3141_1.LEFT_CC.LJPEG  5912  3584   LUMISYS
# 1   B_3141_1.LEFT_MLO.LJPEG  5888  3840   LUMISYS
# 2   B_3141_1.RIGHT_CC.LJPEG  5880  3472   LUMISYS
# 3  B_3141_1.RIGHT_MLO.LJPEG  5936  3848   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3142	 ... found the file B-3142-1.ics
#                          fn  rows  cols digitizer
# 0    B_3142_1.LEFT_CC.LJPEG  4600  3080   LUMISYS
# 1   B_3142_1.LEFT_MLO.LJPEG  4704  2712   LUMISYS
# 2   B_3142_1.RIGHT_CC.LJPEG  4720  2624   LUMISYS
# 3  B_3142_1.RIGHT_MLO.LJPEG  4696  2648   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3143	 ... found the file B-3143-1.ics
#                          fn  rows  cols digitizer
# 0    B_3143_1.LEFT_CC.LJPEG  4776  2568   LUMISYS
# 1   B_3143_1.LEFT_MLO.LJPEG  4704  2776   LUMISYS
# 2   B_3143_1.RIGHT_CC.LJPEG  4688  2840   LUMISYS
# 3  B_3143_1.RIGHT_MLO.LJPEG  4664  2808   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3144	 ... found the file B-3144-1.ics
#                          fn  rows  cols digitizer
# 0    B_3144_1.LEFT_CC.LJPEG  4832  3080   LUMISYS
# 1   B_3144_1.LEFT_MLO.LJPEG  4744  3112   LUMISYS
# 2   B_3144_1.RIGHT_CC.LJPEG  4704  2904   LUMISYS
# 3  B_3144_1.RIGHT_MLO.LJPEG  4744  3176   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3145	 ... found the file B-3145-1.ics
#                          fn  rows  cols digitizer
# 0    B_3145_1.LEFT_CC.LJPEG  4768  2512   LUMISYS
# 1   B_3145_1.LEFT_MLO.LJPEG  4744  2720   LUMISYS
# 2   B_3145_1.RIGHT_CC.LJPEG  4664  2936   LUMISYS
# 3  B_3145_1.RIGHT_MLO.LJPEG  4752  2808   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3146	 ... found the file B-3146-1.ics
#                          fn  rows  cols digitizer
# 0    B_3146_1.LEFT_CC.LJPEG  4800  2864   LUMISYS
# 1   B_3146_1.LEFT_MLO.LJPEG  4776  2688   LUMISYS
# 2   B_3146_1.RIGHT_CC.LJPEG  4816  2728   LUMISYS
# 3  B_3146_1.RIGHT_MLO.LJPEG  4800  2872   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3148	 ... found the file B-3148-1.ics
#                          fn  rows  cols digitizer
# 0    B_3148_1.LEFT_CC.LJPEG  5968  3704   LUMISYS
# 1   B_3148_1.LEFT_MLO.LJPEG  5944  3184   LUMISYS
# 2   B_3148_1.RIGHT_CC.LJPEG  5888  3328   LUMISYS
# 3  B_3148_1.RIGHT_MLO.LJPEG  5960  3680   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3150	 ... found the file B-3150-1.ics
#                          fn  rows  cols digitizer
# 0    B_3150_1.LEFT_CC.LJPEG  4776  2720   LUMISYS
# 1   B_3150_1.LEFT_MLO.LJPEG  4784  2880   LUMISYS
# 2   B_3150_1.RIGHT_CC.LJPEG  4776  2728   LUMISYS
# 3  B_3150_1.RIGHT_MLO.LJPEG  4792  2912   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3151	 ... found the file B-3151-1.ics
#                          fn  rows  cols digitizer
# 0    B_3151_1.LEFT_CC.LJPEG  4768  2832   LUMISYS
# 1   B_3151_1.LEFT_MLO.LJPEG  4752  2432   LUMISYS
# 2   B_3151_1.RIGHT_CC.LJPEG  4768  2872   LUMISYS
# 3  B_3151_1.RIGHT_MLO.LJPEG  4744  2840   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3152	 ... found the file B-3152-1.ics
#                          fn  rows  cols digitizer
# 0    B_3152_1.LEFT_CC.LJPEG  5944  3224   LUMISYS
# 1   B_3152_1.LEFT_MLO.LJPEG  5992  3480   LUMISYS
# 2   B_3152_1.RIGHT_CC.LJPEG  5976  3528   LUMISYS
# 3  B_3152_1.RIGHT_MLO.LJPEG  5976  3560   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3153	 ... found the file B-3153-1.ics
#                          fn  rows  cols digitizer
# 0    B_3153_1.LEFT_CC.LJPEG  4688  2720   LUMISYS
# 1   B_3153_1.LEFT_MLO.LJPEG  4688  2776   LUMISYS
# 2   B_3153_1.RIGHT_CC.LJPEG  4728  2760   LUMISYS
# 3  B_3153_1.RIGHT_MLO.LJPEG  4736  2872   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3154	 ... found the file B-3154-1.ics
#                          fn  rows  cols digitizer
# 0    B_3154_1.LEFT_CC.LJPEG  5936  3560   LUMISYS
# 1   B_3154_1.LEFT_MLO.LJPEG  5792  3560   LUMISYS
# 2   B_3154_1.RIGHT_CC.LJPEG  5936  3856   LUMISYS
# 3  B_3154_1.RIGHT_MLO.LJPEG  5864  3528   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3156	 ... found the file B-3156-1.ics
#                          fn  rows  cols digitizer
# 0    B_3156_1.LEFT_CC.LJPEG  4752  2352   LUMISYS
# 1   B_3156_1.LEFT_MLO.LJPEG  4760  2680   LUMISYS
# 2   B_3156_1.RIGHT_CC.LJPEG  4800  2880   LUMISYS
# 3  B_3156_1.RIGHT_MLO.LJPEG  4736  2680   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3158	 ... found the file B-3158-1.ics
#                          fn  rows  cols digitizer
# 0    B_3158_1.LEFT_CC.LJPEG  4760  2976   LUMISYS
# 1   B_3158_1.LEFT_MLO.LJPEG  4760  2760   LUMISYS
# 2   B_3158_1.RIGHT_CC.LJPEG  4760  2744   LUMISYS
# 3  B_3158_1.RIGHT_MLO.LJPEG  4776  3008   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3159	 ... found the file B-3159-1.ics
#                          fn  rows  cols digitizer
# 0    B_3159_1.LEFT_CC.LJPEG  4544  3120   LUMISYS
# 1   B_3159_1.LEFT_MLO.LJPEG  4536  3112   LUMISYS
# 2   B_3159_1.RIGHT_CC.LJPEG  4616  3088   LUMISYS
# 3  B_3159_1.RIGHT_MLO.LJPEG  4616  3088   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3160	 ... found the file B-3160-1.ics
#                          fn  rows  cols digitizer
# 0    B_3160_1.LEFT_CC.LJPEG  4624  3056   LUMISYS
# 1   B_3160_1.LEFT_MLO.LJPEG  4560  3024   LUMISYS
# 2   B_3160_1.RIGHT_CC.LJPEG  4584  3040   LUMISYS
# 3  B_3160_1.RIGHT_MLO.LJPEG  4600  3032   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3162	 ... found the file B-3162-1.ics
#                          fn  rows  cols digitizer
# 0    B_3162_1.LEFT_CC.LJPEG  4576  3088   LUMISYS
# 1   B_3162_1.LEFT_MLO.LJPEG  4584  3024   LUMISYS
# 2   B_3162_1.RIGHT_CC.LJPEG  4568  3072   LUMISYS
# 3  B_3162_1.RIGHT_MLO.LJPEG  4568  3048   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3165	 ... found the file B-3165-1.ics
#                          fn  rows  cols digitizer
# 0    B_3165_1.LEFT_CC.LJPEG  4552  3016   LUMISYS
# 1   B_3165_1.LEFT_MLO.LJPEG  4528  3032   LUMISYS
# 2   B_3165_1.RIGHT_CC.LJPEG  4568  3064   LUMISYS
# 3  B_3165_1.RIGHT_MLO.LJPEG  4624  3032   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3166	 ... found the file B-3166-1.ics
#                          fn  rows  cols digitizer
# 0    B_3166_1.LEFT_CC.LJPEG  5680  4064   LUMISYS
# 1   B_3166_1.LEFT_MLO.LJPEG  5704  4128   LUMISYS
# 2   B_3166_1.RIGHT_CC.LJPEG  5744  4008   LUMISYS
# 3  B_3166_1.RIGHT_MLO.LJPEG  5760  4080   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3169	 ... found the file B-3169-1.ics
#                          fn  rows  cols digitizer
# 0    B_3169_1.LEFT_CC.LJPEG  4632  3112   LUMISYS
# 1   B_3169_1.LEFT_MLO.LJPEG  4440  3120   LUMISYS
# 2   B_3169_1.RIGHT_CC.LJPEG  4544  3072   LUMISYS
# 3  B_3169_1.RIGHT_MLO.LJPEG  4624  3112   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3175	 ... found the file B-3175-1.ics
#                          fn  rows  cols digitizer
# 0    B_3175_1.LEFT_CC.LJPEG  4616  3048   LUMISYS
# 1   B_3175_1.LEFT_MLO.LJPEG  4544  3040   LUMISYS
# 2   B_3175_1.RIGHT_CC.LJPEG  4592  3040   LUMISYS
# 3  B_3175_1.RIGHT_MLO.LJPEG  4568  3032   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3184	 ... found the file B-3184-1.ics
#                          fn  rows  cols digitizer
# 0    B_3184_1.LEFT_CC.LJPEG  4608  3184   LUMISYS
# 1   B_3184_1.LEFT_MLO.LJPEG  4592  3104   LUMISYS
# 2   B_3184_1.RIGHT_CC.LJPEG  4536  3120   LUMISYS
# 3  B_3184_1.RIGHT_MLO.LJPEG  4600  3112   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3185	 ... found the file B-3185-1.ics
#                          fn  rows  cols digitizer
# 0    B_3185_1.LEFT_CC.LJPEG  4552  3056   LUMISYS
# 1   B_3185_1.LEFT_MLO.LJPEG  4520  3032   LUMISYS
# 2   B_3185_1.RIGHT_CC.LJPEG  4592  3056   LUMISYS
# 3  B_3185_1.RIGHT_MLO.LJPEG  4568  3040   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_01/case3186	 ... found the file B-3186-1.ics
#                          fn  rows  cols digitizer
# 0    B_3186_1.LEFT_CC.LJPEG  5440  4000   LUMISYS
# 1   B_3186_1.LEFT_MLO.LJPEG  5464  4096   LUMISYS
# 2   B_3186_1.RIGHT_CC.LJPEG  5720  3992   LUMISYS
# 3  B_3186_1.RIGHT_MLO.LJPEG  5720  4040   LUMISYS
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_02/case1123	 ... found the file A-1123-1.ics
#                          fn  rows  cols digitizer
# 0    A_1123_1.LEFT_CC.LJPEG  6256  3076    HOWTEK
# 1   A_1123_1.LEFT_MLO.LJPEG  6751  3181    HOWTEK
# 2   A_1123_1.RIGHT_CC.LJPEG  5941  2866    HOWTEK
# 3  A_1123_1.RIGHT_MLO.LJPEG  6736  3241    HOWTEK
#
# In directory: /Users/jnarhan/Code/CUNY7_CapStone/DDSM_Images/cases/benigns/benign_02/case1170	 ... found the file A-1170-1.ics
#                          fn  rows  cols digitizer
# 0    A_1170_1.LEFT_CC.LJPEG  6316  3376    HOWTEK
# 1   A_1170_1.LEFT_MLO.LJPEG  6436  3391    HOWTEK
# 2   A_1170_1.RIGHT_CC.LJPEG  6196  3211    HOWTEK
# 3  A_1170_1.RIGHT_MLO.LJPEG  6466  3196    HOWTEK
